# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7474-15B7
#
#  Directory of C:\Users\kamal\Documents\DATA_scienne_uni\data science project univesrity data visulazation
#
# 02/12/2019  12:59 PM    <DIR>          .
# 02/12/2019  12:59 PM    <DIR>          ..
# 02/12/2019  12:59 PM    <DIR>          .ipynb_checkpoints
# 26/05/2019  04:53 PM           265,926 data.csv
# 02/12/2019  12:59 PM             1,471 p1 data read.ipynb
# 01/12/2019  11:03 AM           180,924 project visulatization.ipynb
# 30/11/2019  11:40 AM    <DIR>          Python-for-Finance-Repo-master
#                3 File(s)        448,321 bytes
#                4 Dir(s)  10,524,573,696 bytes free

# %%
data=pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    Student Registration:            051-18-128533  \
# 0                                           28533
# 1  :                                   ANILA BIBI
# 2             :                               MBA
# 3    :                              BAD-SPRING-19
# 4                                          MGT691
#
#       Student Registration:            051-18-128531  \
# 0                                              28531
# 1  :                                   RAJA DANIY...
# 2                :                               BMS
# 3       :                              ADD-SPRING-19
# 4                                             ADV113
#
#       Student Registration:            051-18-128530  \
# 0                                              28530
# 1  :                                   PAKEEZA TARIQ
# 2                :                               BTD
# 3       :                              ADD-SPRING-19
# 4                                             FPH301
#
# ...

# %%
juck=data.iloc[0:4]

# %%
type(juck)
# Out:
# pandas.core.frame.DataFrame

# %%
juck.transpose()
# Out:
#                                                                            0  \
# Student Registration:            051-18-128533                         28533
# Student Registration:            051-18-128531                         28531
# Student Registration:            051-18-128530                         28530
# Student Registration:            051-18-128528                         28528
# Student Registration:            051-18-128522                         28522
# Student Registration:            051-18-128518                         28518
# Student Registration:            051-18-128517                         28517
# Student Registration:            051-18-128514                         28514
# Student Registration:            051-18-128513                         28513
# Student Registration:            051-18-128512                         28512
# Student Registration:            051-18-128511                         28511
# ...

# %%
sub=data.iloc[5:6]#.unique()
print(type(sub))
#sub.shape
sub.transpose()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                                                                             5
# Student Registration:            051-18-128533                             MANAGEMENT SCIENCE
# Student Registration:            051-18-128531                        ELEMENTS OF ADVERTISING
# Student Registration:            051-18-128530                                    PHOTOGRAPHY
# Student Registration:            051-18-128528  DECENTRALIZATION, PARTICIPATION & DEVELOPMENT
# Student Registration:            051-18-128522                       PRINCIPLES OF ACCOUNTING
# Student Registration:            051-18-128518                                    PHOTOGRAPHY
# Student Registration:            051-18-128517         SPECIAL TOPICS IN SOFTWARE ENGINEERING
# Student Registration:            051-18-128514                                   BUSINESS LAW
# Student Registration:            051-18-128513                     PAKISTAN & ISLAMIC STUDIES
# ...

# %%
data1=data.transpose()

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data1[1].unique()
# Out:
# array([':                                   ANILA BIBI',
#        ':                                   RAJA DANIYAL AHMED ABBASI',
#        ':                                   PAKEEZA TARIQ',
#        ':                                   SYED WAJEEH-UL-HASNAIN',
#        ':                                   USMAN KHAN',
#        ':                                   KINZA REHMAN',
#        ':                                   WAQAS AHMAD',
#        ':                                   SYEDA LABIQUA HASSAN',
#        ':                                   TALHA ALI KHAN ZUBAIRY',
#        ':                                   FAIZA JAVED',
#        ':                                   QAZI ARSALAN AHMAD',
#        ':                                   AHTESHAM YOUNAS',
#        ':                                   AQIB JAN',
#        ':                                   SYED OSAMA WAJID',
#        ':                                   FAIZAN IBRAHIM',
# ...

# %%
data1[5].unique()
# Out:
# array(['MANAGEMENT SCIENCE', 'ELEMENTS OF ADVERTISING', 'PHOTOGRAPHY',
#        'DECENTRALIZATION, PARTICIPATION & DEVELOPMENT',
#        'PRINCIPLES OF ACCOUNTING',
#        'SPECIAL TOPICS IN SOFTWARE ENGINEERING', 'BUSINESS LAW',
#        'PAKISTAN & ISLAMIC STUDIES', 'VIRTUAL DESIGN I',
#        'FINANCIAL ACCOUNTING', 'MANAGEMENT INFORMATION SYSTEMS',
#        'FOREIGN POLICY ANALYSIS', 'W.T.O. & DEVELOPING COUNTRIES',
#        'ESSENTIALS OF ISLAMIC FINANCE', 'CALCULUS-I',
#        'COMPUTER APPLICATIONS', 'CALCULUS-II', 'ENGLISH-II',
#        'ORGANIZATIONAL BEHAVIOUR', 'INTRODUCTION TO BUSINESS FINANCE',
#        'DIGITAL LOGIC DESIGN', 'THEORY OF PROGRAMMING LANGUAGES',
#        'INTERNATIONAL BUSINESS', 'FASHION ILLUSTRATION I',
#        'STRATEGIC FINANCE', 'DIGITAL ILLUSTRATION & MANIPULATION',
#        'MACROECONOMICS', 'MARKETING MANAGEMENT', 'BUSINESS MATHEMATICS',
#        'PRINCIPLES OF MARKETING', 'STATISTICAL INFERENCE FOR MANAGERS',
# ...

# %%
print(data1[6].nunique())
data1[6].unique()
# Out:
# 7
# array(['B+', 'B', 'C+', 'F', 'C', 'A', 'W'], dtype=object)

# %%
data1[7].nunique()
# Out:
# 130

# %%
data1[8].nunique()
# Out:
# 122

# %%
data1[9].unique()
# Out:
# array(['B', 'W', 'C', 'B+', 'A', 'C+', 'F', nan], dtype=object)

# %%
data1.to_csv('data1.csv')
