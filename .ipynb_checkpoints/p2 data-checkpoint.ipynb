# %%
import pandas as pd

# %%
data=pd.read_csv('data1.csv')

# %%
data.head()
# Out:
#                                        Unnamed: 0      0  \
# 0  Student Registration:            051-18-128533  28533
# 1  Student Registration:            051-18-128531  28531
# 2  Student Registration:            051-18-128530  28530
# 3  Student Registration:            051-18-128528  28528
# 4  Student Registration:            051-18-128522  28522
#
#                                                    1  \
# 0     :                                   ANILA BIBI
# 1  :                                   RAJA DANIY...
# 2  :                                   PAKEEZA TARIQ
# 3  :                                   SYED WAJEE...
# 4     :                                   USMAN KHAN
#
#                                           2  \
# 0       :                               MBA
# 1       :                               BMS
# 2       :                               BTD
# 3  :                               M.SC(IR)
# 4     :                               BBA-H
#
#                                               3       4  \
# 0  :                              BAD-SPRING-19  MGT691
# 1  :                              ADD-SPRING-19  ADV113
# 2  :                              ADD-SPRING-19  FPH301
# 3  :                              DSD-SPRING-19   DS604
# 4  :                              BAD-SPRING-19  ACT211
#
#                                                5   6       7  \
# 0                             MANAGEMENT SCIENCE  B+  ACT431
# 1                        ELEMENTS OF ADVERTISING   B  MDS242
# 2                                    PHOTOGRAPHY  C+  TST221
# 3  DECENTRALIZATION, PARTICIPATION & DEVELOPMENT  B+   DS639
# 4                       PRINCIPLES OF ACCOUNTING   F  ASC162
#
#                                                  8  ...   12      13  \
# 0                   COST AND MANAGEMENT ACCOUNTING  ...   C+     NaN
# 1                     CAMERA & LIGHTING TECHNIQUES  ...   C+     NaN
# 2                              SURVEY OF TEXTILE I  ...    C  TNS251
# 3  GLOBALIZATION AND REGIONAL ECONOMIC INTEGRATION  ...   C+     NaN
# 4                             BUSINESS MATHEMATICS  ...  NaN     NaN
#
#                14   15   16   17   18   19   20   21
# 0             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NATURE STUDIES   B+  NaN  NaN  NaN  NaN  NaN  NaN
# 3             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 23 columns]

# %%
data['2'].unique()
# Out:
# array([':                               MBA',
#        ':                               BMS',
#        ':                               BTD',
#        ':                               M.SC(IR)',
#        ':                               BBA-H',
#        ':                               MS(SE)',
#        ':                               BS(SE)',
#        ':                               BS(CS)',
#        ':                               BSDS',
#        ':                               BFD',
#        ':                               MS(CS)',
#        ':                               MS(BA)',
#        ':                               BS(IR)',
#        ':                               ADFD',
#        ':                               BS(A&F)',
#        ':                               BSTN',
#        ':                               MPHIL(IDS)',
#        ':                               BS(ECO)',
#        ':                               MPHIL(IR)',
#        ':                               MS(MGT)',
#        ':                               BS(SC)',
#        ':                               PH.D (CS)',
#        ':                               FDFD',
#        ':                               MSTN',
#        ':                               FDTD',
#        ':                               M.SC(DS)'], dtype=object)

# %%
data[data['2']==":                               BS(SC)"]
# Out:
#                                          Unnamed: 0      0  \
# 298  Student Registration:            051-17-128002  28002
# 586  Student Registration:            051-17-127264  27264
#
#                                                     1  \
# 298  :                                   ANUM RAFIQUE
# 586   :                                   MISBAH FIDA
#
#                                           2  \
# 298  :                               BS(SC)
# 586  :                               BS(SC)
#
#                                                 3      4               5  6  \
# 298  :                              DSD-SPRING-19  DS131  MACROECONOMICS  A
# 586  :                              DSD-SPRING-19  DS131  MACROECONOMICS  C
#
#           7              8  ...   12   13   14   15   16   17   18   19   20  \
# 298  MCJ112  WORLD HISTORY  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 586     NaN            NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#       21
# 298  NaN
# 586  NaN
#
# [2 rows x 23 columns]

# %%
a=':                              BAD-SPRING-19'
print(a[1:].strip())
# Out:
# BAD-SPRING-19

# %%
data['1']=data['1'].apply(lambda x:x[1:].strip())

# %%
data
# Out:
#                                          Unnamed: 0      0  \
# 0    Student Registration:            051-18-128533  28533
# 1    Student Registration:            051-18-128531  28531
# 2    Student Registration:            051-18-128530  28530
# 3    Student Registration:            051-18-128528  28528
# 4    Student Registration:            051-18-128522  28522
# 5    Student Registration:            051-18-128518  28518
# 6    Student Registration:            051-18-128517  28517
# 7    Student Registration:            051-18-128514  28514
# 8    Student Registration:            051-18-128513  28513
# 9    Student Registration:            051-18-128512  28512
# 10   Student Registration:            051-18-128511  28511
# 11   Student Registration:            051-18-128509  28509
# 12   Student Registration:            051-18-128505  28505
# 13   Student Registration:            051-18-128504  28504
# 14   Student Registration:            051-18-128502  28502
# 15   Student Registration:            051-18-128501  28501
# 16   Student Registration:            051-18-128500  28500
# 17   Student Registration:            051-18-128499  28499
# 18   Student Registration:            051-18-128497  28497
# 19   Student Registration:            051-18-128496  28496
# 20   Student Registration:            051-18-128493  28493
# 21   Student Registration:            051-18-128488  28488
# 22   Student Registration:            051-18-128487  28487
# 23   Student Registration:            051-18-128485  28485
# 24   Student Registration:            051-18-128483  28483
# 25   Student Registration:            051-18-128476  28476
# 26   Student Registration:            051-18-128475  28475
# 27   Student Registration:            051-18-128474  28474
# 28   Student Registration:            051-18-128473  28473
# 29   Student Registration:            051-18-128471  28471
# ..                                              ...    ...
# 761  Student Registration:            051-17-126379  26379
# 762  Student Registration:            051-17-126373  26373
# 763  Student Registration:            051-17-126371  26371
# 764  Student Registration:            051-17-126368  26368
# 765  Student Registration:            051-17-126367  26367
# 766  Student Registration:            051-17-126366  26366
# 767  Student Registration:            051-17-126362  26362
# 768  Student Registration:            051-17-126359  26359
# 769  Student Registration:            051-17-126358  26358
# 770  Student Registration:            051-17-126357  26357
# 771  Student Registration:            051-17-126353  26353
# 772  Student Registration:            051-17-126351  26351
# 773  Student Registration:            051-17-126350  26350
# 774  Student Registration:            051-17-126349  26349
# 775  Student Registration:            051-17-126345  26345
# 776  Student Registration:            051-17-126338  26338
# 777  Student Registration:            051-17-126337  26337
# 778  Student Registration:            051-17-126331  26331
# 779  Student Registration:            051-17-126327  26327
# 780  Student Registration:            051-17-126326  26326
# 781  Student Registration:            051-17-126324  26324
# 782  Student Registration:            051-17-126319  26319
# 783  Student Registration:            051-17-126316  26316
# 784  Student Registration:            051-17-126313  26313
# 785  Student Registration:            051-17-126312  26312
# 786  Student Registration:            051-17-126309  26309
# 787  Student Registration:            051-17-126308  26308
# 788  Student Registration:            051-17-126306  26306
# 789  Student Registration:            051-17-126305  26305
# 790  Student Registration:            051-17-126304  26304
#
#                              1                                         2  \
# 0                   ANILA BIBI       :                               MBA
# 1    RAJA DANIYAL AHMED ABBASI       :                               BMS
# 2                PAKEEZA TARIQ       :                               BTD
# 3       SYED WAJEEH-UL-HASNAIN  :                               M.SC(IR)
# 4                   USMAN KHAN     :                               BBA-H
# 5                 KINZA REHMAN       :                               BTD
# 6                  WAQAS AHMAD    :                               MS(SE)
# 7         SYEDA LABIQUA HASSAN     :                               BBA-H
# 8       TALHA ALI KHAN ZUBAIRY    :                               BS(SE)
# 9                  FAIZA JAVED       :                               BTD
# 10          QAZI ARSALAN AHMAD    :                               BS(SE)
# 11             AHTESHAM YOUNAS     :                               BBA-H
# 12                    AQIB JAN     :                               BBA-H
# 13            SYED OSAMA WAJID  :                               M.SC(IR)
# 14              FAIZAN IBRAHIM  :                               M.SC(IR)
# 15     MUHAMMAD ARSLAN SHAUKAT       :                               MBA
# 16               HAIDER SALEEM    :                               BS(CS)
# 17              UMAIR ALI SHAH    :                               BS(CS)
# 18                 FAIZA SAEED      :                               BSDS
# 19                 LAIBA SAEED      :                               BSDS
# 20               ANEEQA BATOOL       :                               BFD
# 21             MUHAMMAD JUNAID    :                               BS(CS)
# 22            MOAZZAMA KULSOOM       :                               BTD
# 23               KIFAYAT ULLAH     :                               BBA-H
# 24            SYED AZMAR AHMAD     :                               BBA-H
# 25              MUHAMMAD MANAN       :                               MBA
# 26               AHSAN RAFIQUE       :                               MBA
# 27                 WARDA ABBAS     :                               BBA-H
# 28                  ZAIN TARIQ     :                               BBA-H
# 29        MUHAMMAD ALI RASHEED    :                               BS(CS)
# ..                         ...                                       ...
# 761              MUEED MANSOOR   :                               BS(A&F)
# 762       OMAR SHAHBAZ KHOKHAR    :                               BS(CS)
# 763             MUHAMMAD TAHIR     :                               BBA-H
# 764           UMER FAROOQ KHAN       :                               BFD
# 765            MAIMOONA SAJJAD      :                               BSDS
# 766               HAMID TAZEEM    :                               BS(CS)
# 767      MUHAMMAD SUMRAZ KUNDI    :                               BS(CS)
# 768            SYEDA SANWA ALI       :                               BMS
# 769               SHAFAQ EHSAN  :                               M.SC(IR)
# 770              TALHA MEHBOOB     :                               BBA-H
# 771             MUHAMMAD ISHAQ    :                               BS(CS)
# 772           KAMRAN NADIR ALI    :                               BS(CS)
# 773                 MOIZ ABRAR     :                               BBA-H
# 774              FAIZAN HAIDER    :                               BS(IR)
# 775         USMAN HASSAN ABBAS       :                               BMS
# 776              ZEESHAN AMJAD    :                               BS(IR)
# 777                 HASEEB ALI       :                               BFD
# 778                SEEMA KARIM    :                               BS(IR)
# 779                ZOHAIB KHAN       :                               MBA
# 780               ARSHIA WAQAR      :                               BSDS
# 781                AQSA ZAHEER    :                               BS(IR)
# 782      SHEIKH ABDULLAH NASIR    :                               BS(CS)
# 783            WAJAHAT HUSSAIN     :                               BBA-H
# 784        SYEDA TATHEER ZAHRA  :                               M.SC(IR)
# 785             SHAHRYAR ALTAF     :                               BBA-H
# 786          HAREEM ALI GHAURI       :                               BFD
# 787               HAMZA BALOCH    :                               BS(SE)
# 788                 ALI HAIDER     :                               BBA-H
# 789                FARVA SAEED       :                               MBA
# 790             MUHAMMAD SAMIM     :                               BBA-H
#
#                                                 3       4  \
# 0    :                              BAD-SPRING-19  MGT691
# 1    :                              ADD-SPRING-19  ADV113
# 2    :                              ADD-SPRING-19  FPH301
# 3    :                              DSD-SPRING-19   DS604
# 4    :                              BAD-SPRING-19  ACT211
# 5    :                              ADD-SPRING-19  FPH301
# 6    :                              CSD-SPRING-19  CSC534
# 7    :                              BAD-SPRING-19  BUS312
# 8    :                              CSD-SPRING-19  HMT105
# 9    :                              ADD-SPRING-19  FVD272
# 10   :                              CSD-SPRING-19  HMT105
# 11   :                              BAD-SPRING-19  ACT202
# 12   :                              BAD-SPRING-19  MIS222
# 13   :                              DSD-SPRING-19   IR510
# 14   :                              DSD-SPRING-19   DS634
# 15   :                              BAD-SPRING-19  FIN301
# 16   :                              CSD-SPRING-19  ASC101
# 17   :                              CSD-SPRING-19  ASC101
# 18   :                              DSD-SPRING-19  HMT105
# 19   :                              DSD-SPRING-19  HMT105
# 20   :                              ADD-SPRING-19  CSC100
# 21   :                              CSD-SPRING-19  ASC201
# 22   :                              ADD-SPRING-19  FPH301
# 23   :                              BAD-SPRING-19  ACT202
# 24   :                              BAD-SPRING-19  HMT102
# 25   :                              BAD-SPRING-19  MGT311
# 26   :                              BAD-SPRING-19  FIN311
# 27   :                              BAD-SPRING-19  ACT211
# 28   :                              BAD-SPRING-19  ACT211
# 29   :                              CSD-SPRING-19  CSC212
# ..                                            ...     ...
# 761  :                              BAD-SPRING-19  MIS222
# 762  :                              CSD-SPRING-19  MGT431
# 763  :                              BAD-SPRING-19  FIN201
# 764  :                              ADD-SPRING-19  HMT301
# 765  :                              DSD-SPRING-19   DS230
# 766  :                              CSD-SPRING-19  HMT311
# 767  :                              CSD-SPRING-19  HMT311
# 768  :                              ADD-SPRING-19  HMT215
# 769  :                              DSD-SPRING-19   DS604
# 770  :                              BAD-SPRING-19  MIS222
# 771  :                              CSD-SPRING-19  ASC101
# 772  :                              CSD-SPRING-19  ASC203
# 773  :                              BAD-SPRING-19  FIN201
# 774  :                              DSD-SPRING-19   DS243
# 775  :                              ADD-SPRING-19  ADV312
# 776  :                              DSD-SPRING-19   DS243
# 777  :                              ADD-SPRING-19  FVD372
# 778  :                              DSD-SPRING-19   DS121
# 779  :                              BAD-SPRING-19  ASC361
# 780  :                              DSD-SPRING-19   DS121
# 781  :                              DSD-SPRING-19   DS480
# 782  :                              CSD-SPRING-19  ASC201
# 783  :                              BAD-SPRING-19  ECO221
# 784  :                              DSD-SPRING-19   DS604
# 785  :                              BAD-SPRING-19  BUS312
# 786  :                              ADD-SPRING-19  FIL211
# 787  :                              CSD-SPRING-19  MGT201
# 788  :                              BAD-SPRING-19  ACT202
# 789  :                              BAD-SPRING-19  MGT691
# 790  :                              BAD-SPRING-19  BUS312
#
#                                                  5   6       7  \
# 0                               MANAGEMENT SCIENCE  B+  ACT431
# 1                          ELEMENTS OF ADVERTISING   B  MDS242
# 2                                      PHOTOGRAPHY  C+  TST221
# 3    DECENTRALIZATION, PARTICIPATION & DEVELOPMENT  B+   DS639
# 4                         PRINCIPLES OF ACCOUNTING   F  ASC162
# 5                                      PHOTOGRAPHY  B+  TWD211
# 6           SPECIAL TOPICS IN SOFTWARE ENGINEERING   C  CSE504
# 7                                     BUSINESS LAW  B+  MAT211
# 8                       PAKISTAN & ISLAMIC STUDIES  B+  HMT311
# 9                                 VIRTUAL DESIGN I  B+  FPH301
# 10                      PAKISTAN & ISLAMIC STUDIES  C+  CSC102
# 11                            FINANCIAL ACCOUNTING   B  HMT216
# 12                  MANAGEMENT INFORMATION SYSTEMS  C+  ACT202
# 13                         FOREIGN POLICY ANALYSIS   F   DS634
# 14                   W.T.O. & DEVELOPING COUNTRIES   B   IR601
# 15                   ESSENTIALS OF ISLAMIC FINANCE   F  MAT312
# 16                                      CALCULUS-I  C+  CSC212
# 17                                      CALCULUS-I   B  CSC212
# 18                      PAKISTAN & ISLAMIC STUDIES  B+  HMT102
# 19                      PAKISTAN & ISLAMIC STUDIES  B+  HMT102
# 20                           COMPUTER APPLICATIONS   C  FIL211
# 21                                     CALCULUS-II   C  ASC341
# 22                                     PHOTOGRAPHY   B  TWD211
# 23                            FINANCIAL ACCOUNTING   A  HMT216
# 24                                      ENGLISH-II  B+  ECO211
# 25                        ORGANIZATIONAL BEHAVIOUR  C+  SCM421
# 26                INTRODUCTION TO BUSINESS FINANCE   B  BUS101
# 27                        PRINCIPLES OF ACCOUNTING   F  ASC162
# 28                        PRINCIPLES OF ACCOUNTING   F  HMT102
# 29                            DIGITAL LOGIC DESIGN  C+  ASC304
# ..                                             ...  ..     ...
# 761                 MANAGEMENT INFORMATION SYSTEMS   B  FIN201
# 762                               ENTREPRENEURSHIP  C+  CSC441
# 763               INTRODUCTION TO BUSINESS FINANCE  C+  ECO221
# 764                                      SOCIOLOGY   W     NaN
# 765                INTERNATIONAL POLITICAL ECONOMY  B+  HMT401
# 766                           LANGUAGE PROFICIENCY   B  CSC441
# 767                           LANGUAGE PROFICIENCY   B  CSC441
# 768                         BUSINESS COMMUNICATION  B+  FTV481
# 769  DECENTRALIZATION, PARTICIPATION & DEVELOPMENT  B+   DS634
# 770                 MANAGEMENT INFORMATION SYSTEMS   B  ACT202
# 771                                     CALCULUS-I  C+  CSC211
# 772                           DISCRETE MATHEMATICS  B+  ASC201
# 773               INTRODUCTION TO BUSINESS FINANCE   F  ECO221
# 774                        FOREIGN POLICY ANALYSIS  B+   DS441
# 775                                   MEDIA DESIGN   F  FTV481
# 776                        FOREIGN POLICY ANALYSIS   C   DS230
# 777                              VIRTUAL DESIGN II   A  FPM223
# 778                              WOMEN AND SOCIETY  B+   DS480
# 779             STATISTICAL INFERENCE FOR MANAGERS   C  SCM421
# 780                              WOMEN AND SOCIETY   A   DS131
# 781                              INTERNATIONAL LAW   C   DS340
# 782                                    CALCULUS-II   C  ASC341
# 783                                 MACROECONOMICS   C  MAT211
# 784  DECENTRALIZATION, PARTICIPATION & DEVELOPMENT   A   DS634
# 785                                   BUSINESS LAW  B+  ECO221
# 786                         FASHION ILLUSTRATION I   C  FPM222
# 787                       PRINCIPLES OF MANAGEMENT  C+  CSE342
# 788                           FINANCIAL ACCOUNTING   F  ECO221
# 789                             MANAGEMENT SCIENCE  C+  MGT692
# 790                                   BUSINESS LAW  C+  MAT211
#
#                                                    8  ...   12      13  \
# 0                     COST AND MANAGEMENT ACCOUNTING  ...   C+     NaN
# 1                       CAMERA & LIGHTING TECHNIQUES  ...   C+     NaN
# 2                                SURVEY OF TEXTILE I  ...    C  TNS251
# 3    GLOBALIZATION AND REGIONAL ECONOMIC INTEGRATION  ...   C+     NaN
# 4                               BUSINESS MATHEMATICS  ...  NaN     NaN
# 5                                     WOVEN DESIGN I  ...   B+  THT231
# 6                        SOFTWARE PROJECT MANAGEMENT  ...    B     NaN
# 7                              QUANTITATIVE ANALYSIS  ...    B     NaN
# 8                               LANGUAGE PROFICIENCY  ...    F  CSE212
# 9                                        PHOTOGRAPHY  ...   B+  TST221
# 10                              COMPUTER PROGRAMMING  ...    C  CSE212
# 11                              INTERPERSONAL SKILLS  ...  NaN     NaN
# 12                              FINANCIAL ACCOUNTING  ...    B     NaN
# 13                     W.T.O. & DEVELOPING COUNTRIES  ...    A   IR513
# 14                  FOREIGN POLICIES OF GREAT POWERS  ...   B+     NaN
# 15                 BUSINESS MATHEMATICS & STATISTICS  ...    C  FIN311
# 16                              DIGITAL LOGIC DESIGN  ...   B+     NaN
# 17                              DIGITAL LOGIC DESIGN  ...   C+     NaN
# 18                                        ENGLISH-II  ...   C+     NaN
# 19                                        ENGLISH-II  ...   C+     NaN
# 20                            FASHION ILLUSTRATION I  ...   C+  FMS232
# 21              LINEAR ALGEBRA AND COMPLEX VARIABLES  ...    B  ASC304
# 22                                    WOVEN DESIGN I  ...    W  THT231
# 23                              INTERPERSONAL SKILLS  ...  NaN     NaN
# 24                                    MICROECONOMICS  ...    W     NaN
# 25                           SUPPLY CHAIN MANAGEMENT  ...    B  FIN311
# 26                          INTRODUCTION TO BUSINESS  ...    C  MGT692
# 27                              BUSINESS MATHEMATICS  ...    F  HMT216
# 28                                        ENGLISH-II  ...    F  MIS222
# 29                          PROBABILITY & STATISTICS  ...  NaN     NaN
# ..                                               ...  ...  ...     ...
# 761                 INTRODUCTION TO BUSINESS FINANCE  ...    C     NaN
# 762                DESIGN AND ANALYSIS OF ALGORITHMS  ...    B  CSC342
# 763                                   MACROECONOMICS  ...    A     NaN
# 764                                              NaN  ...  NaN     NaN
# 765                      RESEARCH METHODS AND SKILLS  ...  NaN     NaN
# 766                DESIGN AND ANALYSIS OF ALGORITHMS  ...    A  CSC342
# 767                DESIGN AND ANALYSIS OF ALGORITHMS  ...    A  CSC385
# 768                            AESTHETICS OF EDITING  ...    B  FTV461
# 769                    W.T.O. & DEVELOPING COUNTRIES  ...   B+   DS528
# 770                             FINANCIAL ACCOUNTING  ...   B+     NaN
# 771                    DATA STRUCTURE AND ALGORITHMS  ...    C     NaN
# 772                                      CALCULUS-II  ...    F  CSC351
# 773                                   MACROECONOMICS  ...    C     NaN
# 774                 FOREIGN POLICIES OF GREAT POWERS  ...    A     NaN
# 775                            AESTHETICS OF EDITING  ...    C  FTV354
# 776                  INTERNATIONAL POLITICAL ECONOMY  ...    B     NaN
# 777                               PATTERN MAKING III  ...    A  FIL313
# 778                                INTERNATIONAL LAW  ...   B+     NaN
# 779                          SUPPLY CHAIN MANAGEMENT  ...    B     NaN
# 780                                   MACROECONOMICS  ...   B+     NaN
# 781        MODERN HISTORY OF INTERNATIONAL RELATIONS  ...  NaN     NaN
# 782             LINEAR ALGEBRA AND COMPLEX VARIABLES  ...    B  CSC313
# 783                            QUANTITATIVE ANALYSIS  ...  NaN     NaN
# 784                    W.T.O. & DEVELOPING COUNTRIES  ...   B+   DS528
# 785                                   MACROECONOMICS  ...   B+  BUS371
# 786                                PATTERN MAKING II  ...    C  FMS233
# 787                                OPERATING SYSTEMS  ...   C+     NaN
# 788                                   MACROECONOMICS  ...  NaN     NaN
# 789              QUANTITATIVE TECHNIQUES IN ANALYSIS  ...   C+     NaN
# 790                            QUANTITATIVE ANALYSIS  ...  NaN     NaN
#
#                                       14   15      16  \
# 0                                    NaN  NaN     NaN
# 1                                    NaN  NaN     NaN
# 2                         NATURE STUDIES   B+     NaN
# 3                                    NaN  NaN     NaN
# 4                                    NaN  NaN     NaN
# 5                   HISTORY OF TEXTILE I   B+  TNS251
# 6                                    NaN  NaN     NaN
# 7                                    NaN  NaN     NaN
# 8                   DIGITAL LOGIC DESIGN    B  CSE213
# 9                    SURVEY OF TEXTILE I   B+  THT231
# 10                  DIGITAL LOGIC DESIGN   C+     NaN
# 11                                   NaN  NaN     NaN
# 12                                   NaN  NaN     NaN
# 13      GLOBALIZATION AND WORLD POLITICS   B+     NaN
# 14                                   NaN  NaN     NaN
# 15      INTRODUCTION TO BUSINESS FINANCE    F     NaN
# 16                                   NaN  NaN     NaN
# 17                                   NaN  NaN     NaN
# 18                                   NaN  NaN     NaN
# 19                                   NaN  NaN     NaN
# 20                     MACHINE SEWING II   B+     NaN
# 21              PROBABILITY & STATISTICS    F  CSC211
# 22                  HISTORY OF TEXTILE I    C  TNS251
# 23                                   NaN  NaN     NaN
# 24                                   NaN  NaN     NaN
# 25      INTRODUCTION TO BUSINESS FINANCE   B+     NaN
# 26   QUANTITATIVE TECHNIQUES IN ANALYSIS   C+     NaN
# 27                  INTERPERSONAL SKILLS    I     NaN
# 28        MANAGEMENT INFORMATION SYSTEMS    F     NaN
# 29                                   NaN  NaN     NaN
# ..                                   ...  ...     ...
# 761                                  NaN  NaN     NaN
# 762                    OPERATING SYSTEMS    A     NaN
# 763                                  NaN  NaN     NaN
# 764                                  NaN  NaN     NaN
# 765                                  NaN  NaN     NaN
# 766                    OPERATING SYSTEMS    B  CSC205
# 767          DATABASE MANAGEMENT SYSTEMS   B+  CSC342
# 768                           PRODUCTION    B  FTV354
# 769               GENDER AND DEVELOPMENT   C+     NaN
# 770                                  NaN  NaN     NaN
# 771                                  NaN  NaN     NaN
# 772               SOFTWARE ENGINEERING I    B  CSC313
# 773                                  NaN  NaN     NaN
# 774                                  NaN  NaN     NaN
# 775                         SOUND DESIGN    B     NaN
# 776                                  NaN  NaN     NaN
# 777             FASHION ILLUSTRATION III    A  FMM361
# 778                                  NaN  NaN     NaN
# 779                                  NaN  NaN     NaN
# 780                                  NaN  NaN     NaN
# 781                                  NaN  NaN     NaN
# 782        DATA COMMUNICATION & NETWORKS    F  ASC304
# 783                                  NaN  NaN     NaN
# 784               GENDER AND DEVELOPMENT   B+   IR604
# 785           FUNDAMENTALS OF E-COMMERCE    C     NaN
# 786                   MACHINE SEWING III    B  FDR222
# 787                                  NaN  NaN     NaN
# 788                                  NaN  NaN     NaN
# 789                                  NaN  NaN     NaN
# 790                                  NaN  NaN     NaN
#
#                                        17   18      19  \
# 0                                     NaN  NaN     NaN
# 1                                     NaN  NaN     NaN
# 2                                     NaN  NaN     NaN
# 3                                     NaN  NaN     NaN
# 4                                     NaN  NaN     NaN
# 5                          NATURE STUDIES    A     NaN
# 6                                     NaN  NaN     NaN
# 7                                     NaN  NaN     NaN
# 8    INTRODUCTION TO SOFTWARE ENGINEERING    A     NaN
# 9                    HISTORY OF TEXTILE I    C     NaN
# 10                                    NaN  NaN     NaN
# 11                                    NaN  NaN     NaN
# 12                                    NaN  NaN     NaN
# 13                                    NaN  NaN     NaN
# 14                                    NaN  NaN     NaN
# 15                                    NaN  NaN     NaN
# 16                                    NaN  NaN     NaN
# 17                                    NaN  NaN     NaN
# 18                                    NaN  NaN     NaN
# 19                                    NaN  NaN     NaN
# 20                                    NaN  NaN     NaN
# 21          DATA STRUCTURE AND ALGORITHMS    F     NaN
# 22                         NATURE STUDIES   B+  TPD252
# 23                                    NaN  NaN     NaN
# 24                                    NaN  NaN     NaN
# 25                                    NaN  NaN     NaN
# 26                                    NaN  NaN     NaN
# 27                                    NaN  NaN     NaN
# 28                                    NaN  NaN     NaN
# 29                                    NaN  NaN     NaN
# ..                                    ...  ...     ...
# 761                                   NaN  NaN     NaN
# 762                                   NaN  NaN     NaN
# 763                                   NaN  NaN     NaN
# 764                                   NaN  NaN     NaN
# 765                                   NaN  NaN     NaN
# 766           OBJECT ORIENTED PROGRAMMING    A     NaN
# 767                     OPERATING SYSTEMS   C+     NaN
# 768                          SOUND DESIGN   C+     NaN
# 769                                   NaN  NaN     NaN
# 770                                   NaN  NaN     NaN
# 771                                   NaN  NaN     NaN
# 772         DATA COMMUNICATION & NETWORKS    F     NaN
# 773                                   NaN  NaN     NaN
# 774                                   NaN  NaN     NaN
# 775                                   NaN  NaN     NaN
# 776                                   NaN  NaN     NaN
# 777             MARKETING & MERCHANDISING   B+  HMT401
# 778                                   NaN  NaN     NaN
# 779                                   NaN  NaN     NaN
# 780                                   NaN  NaN     NaN
# 781                                   NaN  NaN     NaN
# 782              PROBABILITY & STATISTICS    B     NaN
# 783                                   NaN  NaN     NaN
# 784  WORLD PEACE: ISSUES AND PERSPECTIVES    A     NaN
# 785                                   NaN  NaN     NaN
# 786                            DRAPING II    C     NaN
# 787                                   NaN  NaN     NaN
# 788                                   NaN  NaN     NaN
# 789                                   NaN  NaN     NaN
# 790                                   NaN  NaN     NaN
#
#                               20   21
# 0                            NaN  NaN
# 1                            NaN  NaN
# 2                            NaN  NaN
# 3                            NaN  NaN
# 4                            NaN  NaN
# 5                            NaN  NaN
# 6                            NaN  NaN
# 7                            NaN  NaN
# 8                            NaN  NaN
# 9                            NaN  NaN
# 10                           NaN  NaN
# 11                           NaN  NaN
# 12                           NaN  NaN
# 13                           NaN  NaN
# 14                           NaN  NaN
# 15                           NaN  NaN
# 16                           NaN  NaN
# 17                           NaN  NaN
# 18                           NaN  NaN
# 19                           NaN  NaN
# 20                           NaN  NaN
# 21                           NaN  NaN
# 22               PRINT DESIGN II    W
# 23                           NaN  NaN
# 24                           NaN  NaN
# 25                           NaN  NaN
# 26                           NaN  NaN
# 27                           NaN  NaN
# 28                           NaN  NaN
# 29                           NaN  NaN
# ..                           ...  ...
# 761                          NaN  NaN
# 762                          NaN  NaN
# 763                          NaN  NaN
# 764                          NaN  NaN
# 765                          NaN  NaN
# 766                          NaN  NaN
# 767                          NaN  NaN
# 768                          NaN  NaN
# 769                          NaN  NaN
# 770                          NaN  NaN
# 771                          NaN  NaN
# 772                          NaN  NaN
# 773                          NaN  NaN
# 774                          NaN  NaN
# 775                          NaN  NaN
# 776                          NaN  NaN
# 777  RESEARCH METHODS AND SKILLS   C+
# 778                          NaN  NaN
# 779                          NaN  NaN
# 780                          NaN  NaN
# 781                          NaN  NaN
# 782                          NaN  NaN
# 783                          NaN  NaN
# 784                          NaN  NaN
# 785                          NaN  NaN
# 786                          NaN  NaN
# 787                          NaN  NaN
# 788                          NaN  NaN
# 789                          NaN  NaN
# 790                          NaN  NaN
#
# [791 rows x 23 columns]

# %%
data['2']=data['2'].apply(lambda x:x[1:].strip())

# %%
data['3']=data['3'].apply(lambda x:x[1:].strip())

# %%
data['6'].unique()
# Out:
# array(['B+', 'B', 'C+', 'F', 'C', 'A', 'W'], dtype=object)

# %%
data.to_csv('data2.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-12-6f5691562102> in <module>
# ----> 1 data.to_csv('data2.csv',index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'data2.csv'

# %%
data=pd.read_csv('data2.csv')

# %%
data['0'].nunique()
print('Totel student = {0}'.format(data['0'].nunique()))
# Out:
# Totel student = 791

# %%
data['3'].unique()
# Out:
# array(['BAD-SPRING-19', 'ADD-SPRING-19', 'DSD-SPRING-19', 'CSD-SPRING-19'],
#       dtype=object)

# %%
print(data['2'].unique(),end='\n\n') 
print('Totel number of degree are = {}'.format(data['2'].nunique()))
# Out:
# ['MBA' 'BMS' 'BTD' 'M.SC(IR)' 'BBA-H' 'MS(SE)' 'BS(SE)' 'BS(CS)' 'BSDS'
#  'BFD' 'MS(CS)' 'MS(BA)' 'BS(IR)' 'ADFD' 'BS(A&F)' 'BSTN' 'MPHIL(IDS)'
#  'BS(ECO)' 'MPHIL(IR)' 'MS(MGT)' 'BS(SC)' 'PH.D (CS)' 'FDFD' 'MSTN' 'FDTD'
#  'M.SC(DS)']
#
# Totel number of degree are = 26

# %%
data[(data['2']=="BS(CS)")&(data['6']=='A')|(data['9']=='A')|(data['12']=='A')|(data['15']=='A')|(data['18']=='A')|(data['21']=='A')].shape
# Out:
# (169, 23)

# %%
for i in ['MBA', 'BMS', 'BTD', 'M.SC(IR)', 'BBA-H', 'MS(SE)', 'BS(SE)',
       'BS(CS)', 'BSDS', 'BFD', 'MS(CS)', 'MS(BA)', 'BS(IR)', 'ADFD',
       'BS(A&F)', 'BSTN', 'MPHIL(IDS)', 'BS(ECO)', 'MPHIL(IR)', 'MS(MGT)',
       'BS(SC)', 'PH.D (CS)', 'FDFD', 'MSTN', 'FDTD', 'M.SC(DS)']:
    A=data[(data['2']==i)&(data['6']=='A')|(data['9']=='A')|(data['12']=='A')|(data['15']=='A')|(data['18']=='A')|(data['21']=='A')].shape
    print('Degree {0} \n number of A =    {1}\n\n '.format(i,A[0]))
# Out:
# Degree MBA
#  number of A =    168
#
#
# Degree BMS
#  number of A =    163
#
#
# Degree BTD
#  number of A =    163
#
#
# Degree M.SC(IR)
#  number of A =    165
#
#
# Degree BBA-H
#  number of A =    170
#
#
# Degree MS(SE)
#  number of A =    164
#
#
# Degree BS(SE)
#  number of A =    165
#
#
# Degree BS(CS)
#  number of A =    169
#
#
# Degree BSDS
#  number of A =    165
#
#
# Degree BFD
#  number of A =    164
#
#
# Degree MS(CS)
#  number of A =    164
#
#
# Degree MS(BA)
#  number of A =    163
#
#
# Degree BS(IR)
#  number of A =    168
#
#
# Degree ADFD
#  number of A =    163
#
#
# Degree BS(A&F)
#  number of A =    163
#
#
# Degree BSTN
#  number of A =    163
#
#
# Degree MPHIL(IDS)
#  number of A =    163
#
#
# Degree BS(ECO)
#  number of A =    163
#
#
# Degree MPHIL(IR)
#  number of A =    163
#
#
# Degree MS(MGT)
#  number of A =    165
#
#
# Degree BS(SC)
#  number of A =    164
#
#
# Degree PH.D (CS)
#  number of A =    163
#
#
# Degree FDFD
#  number of A =    163
#
#
# Degree MSTN
#  number of A =    163
#
#
# Degree FDTD
#  number of A =    163
#
#
# Degree M.SC(DS)
#  number of A =    163

# %%
def grade_calculator(dep,grad):
    s=data[(data['2']==dep) &(data['6']==grad)|(data['9']==grad)|(data['12']==grad)|(data['15']==grad)|(data['18']==grad)|(data['21']==grad)].shape
    return s[0]

# %%
Dict={}
for c,j in enumerate(['B+', 'B', 'C+', 'F', 'C', 'A', 'W']):
    for i in ['MBA', 'BMS', 'BTD', 'M.SC(IR)', 'BBA-H', 'MS(SE)', 'BS(SE)',
       'BS(CS)', 'BSDS', 'BFD', 'MS(CS)', 'MS(BA)', 'BS(IR)', 'ADFD',
       'BS(A&F)', 'BSTN', 'MPHIL(IDS)', 'BS(ECO)', 'MPHIL(IR)', 'MS(MGT)',
       'BS(SC)', 'PH.D (CS)', 'FDFD', 'MSTN', 'FDTD', 'M.SC(DS)']:
     #print(grade_calculator(i,j) )
     print('Degree {0} \n number of {1} =    {2}\n\n '.format(i,j,grade_calculator(i,j) ))
# Out:
# Degree MBA
#  number of B+ =    245
#
#
# Degree BMS
#  number of B+ =    240
#
#
# Degree BTD
#  number of B+ =    241
#
#
# Degree M.SC(IR)
#  number of B+ =    239
#
#
# Degree BBA-H
#  number of B+ =    253
#
#
# Degree MS(SE)
#  number of B+ =    241
#
#
# Degree BS(SE)
#  number of B+ =    247
#
#
# Degree BS(CS)
#  number of B+ =    249
#
#
# Degree BSDS
#  number of B+ =    240
#
#
# Degree BFD
#  number of B+ =    239
#
#
# Degree MS(CS)
#  number of B+ =    239
#
#
# Degree MS(BA)
#  number of B+ =    238
#
#
# Degree BS(IR)
#  number of B+ =    246
#
#
# Degree ADFD
#  number of B+ =    237
#
#
# Degree BS(A&F)
#  number of B+ =    237
#
#
# Degree BSTN
#  number of B+ =    237
#
#
# Degree MPHIL(IDS)
#  number of B+ =    238
#
#
# Degree BS(ECO)
#  number of B+ =    237
#
#
# Degree MPHIL(IR)
#  number of B+ =    237
#
#
# Degree MS(MGT)
#  number of B+ =    237
#
#
# Degree BS(SC)
#  number of B+ =    237
#
#
# Degree PH.D (CS)
#  number of B+ =    237
#
#
# Degree FDFD
#  number of B+ =    237
#
#
# Degree MSTN
#  number of B+ =    237
#
#
# Degree FDTD
#  number of B+ =    237
#
#
# Degree M.SC(DS)
#  number of B+ =    237
#
#
# Degree MBA
#  number of B =    334
#
#
# Degree BMS
#  number of B =    323
#
#
# Degree BTD
#  number of B =    322
#
#
# Degree M.SC(IR)
#  number of B =    321
#
#
# Degree BBA-H
#  number of B =    337
#
#
# Degree MS(SE)
#  number of B =    320
#
#
# Degree BS(SE)
#  number of B =    335
#
#
# Degree BS(CS)
#  number of B =    335
#
#
# Degree BSDS
#  number of B =    322
#
#
# Degree BFD
#  number of B =    322
#
#
# Degree MS(CS)
#  number of B =    320
#
#
# Degree MS(BA)
#  number of B =    320
#
#
# Degree BS(IR)
#  number of B =    325
#
#
# Degree ADFD
#  number of B =    321
#
#
# Degree BS(A&F)
#  number of B =    321
#
#
# Degree BSTN
#  number of B =    320
#
#
# Degree MPHIL(IDS)
#  number of B =    320
#
#
# Degree BS(ECO)
#  number of B =    320
#
#
# Degree MPHIL(IR)
#  number of B =    320
#
#
# Degree MS(MGT)
#  number of B =    320
#
#
# Degree BS(SC)
#  number of B =    320
#
#
# Degree PH.D (CS)
#  number of B =    320
#
#
# Degree FDFD
#  number of B =    320
#
#
# Degree MSTN
#  number of B =    320
#
#
# Degree FDTD
#  number of B =    320
#
#
# Degree M.SC(DS)
#  number of B =    320
#
#
# Degree MBA
#  number of C+ =    323
#
#
# Degree BMS
#  number of C+ =    314
#
#
# Degree BTD
#  number of C+ =    314
#
#
# Degree M.SC(IR)
#  number of C+ =    314
#
#
# Degree BBA-H
#  number of C+ =    334
#
#
# Degree MS(SE)
#  number of C+ =    313
#
#
# Degree BS(SE)
#  number of C+ =    319
#
#
# Degree BS(CS)
#  number of C+ =    328
#
#
# Degree BSDS
#  number of C+ =    314
#
#
# Degree BFD
#  number of C+ =    317
#
#
# Degree MS(CS)
#  number of C+ =    313
#
#
# Degree MS(BA)
#  number of C+ =    313
#
#
# Degree BS(IR)
#  number of C+ =    317
#
#
# Degree ADFD
#  number of C+ =    313
#
#
# Degree BS(A&F)
#  number of C+ =    313
#
#
# Degree BSTN
#  number of C+ =    313
#
#
# Degree MPHIL(IDS)
#  number of C+ =    314
#
#
# Degree BS(ECO)
#  number of C+ =    313
#
#
# Degree MPHIL(IR)
#  number of C+ =    314
#
#
# Degree MS(MGT)
#  number of C+ =    313
#
#
# Degree BS(SC)
#  number of C+ =    313
#
#
# Degree PH.D (CS)
#  number of C+ =    314
#
#
# Degree FDFD
#  number of C+ =    314
#
#
# Degree MSTN
#  number of C+ =    313
#
#
# Degree FDTD
#  number of C+ =    313
#
#
# Degree M.SC(DS)
#  number of C+ =    313
#
#
# Degree MBA
#  number of F =    177
#
#
# Degree BMS
#  number of F =    174
#
#
# Degree BTD
#  number of F =    172
#
#
# Degree M.SC(IR)
#  number of F =    174
#
#
# Degree BBA-H
#  number of F =    182
#
#
# Degree MS(SE)
#  number of F =    172
#
#
# Degree BS(SE)
#  number of F =    175
#
#
# Degree BS(CS)
#  number of F =    182
#
#
# Degree BSDS
#  number of F =    172
#
#
# Degree BFD
#  number of F =    175
#
#
# Degree MS(CS)
#  number of F =    172
#
#
# Degree MS(BA)
#  number of F =    172
#
#
# Degree BS(IR)
#  number of F =    177
#
#
# Degree ADFD
#  number of F =    172
#
#
# Degree BS(A&F)
#  number of F =    172
#
#
# Degree BSTN
#  number of F =    172
#
#
# Degree MPHIL(IDS)
#  number of F =    172
#
#
# Degree BS(ECO)
#  number of F =    172
#
#
# Degree MPHIL(IR)
#  number of F =    172
#
#
# Degree MS(MGT)
#  number of F =    172
#
#
# Degree BS(SC)
#  number of F =    172
#
#
# Degree PH.D (CS)
#  number of F =    172
#
#
# Degree FDFD
#  number of F =    172
#
#
# Degree MSTN
#  number of F =    172
#
#
# Degree FDTD
#  number of F =    172
#
#
# Degree M.SC(DS)
#  number of F =    172
#
#
# Degree MBA
#  number of C =    280
#
#
# Degree BMS
#  number of C =    273
#
#
# Degree BTD
#  number of C =    266
#
#
# Degree M.SC(IR)
#  number of C =    266
#
#
# Degree BBA-H
#  number of C =    287
#
#
# Degree MS(SE)
#  number of C =    267
#
#
# Degree BS(SE)
#  number of C =    277
#
#
# Degree BS(CS)
#  number of C =    289
#
#
# Degree BSDS
#  number of C =    266
#
#
# Degree BFD
#  number of C =    268
#
#
# Degree MS(CS)
#  number of C =    267
#
#
# Degree MS(BA)
#  number of C =    267
#
#
# Degree BS(IR)
#  number of C =    270
#
#
# Degree ADFD
#  number of C =    266
#
#
# Degree BS(A&F)
#  number of C =    266
#
#
# Degree BSTN
#  number of C =    268
#
#
# Degree MPHIL(IDS)
#  number of C =    266
#
#
# Degree BS(ECO)
#  number of C =    266
#
#
# Degree MPHIL(IR)
#  number of C =    266
#
#
# Degree MS(MGT)
#  number of C =    266
#
#
# Degree BS(SC)
#  number of C =    267
#
#
# Degree PH.D (CS)
#  number of C =    266
#
#
# Degree FDFD
#  number of C =    266
#
#
# Degree MSTN
#  number of C =    266
#
#
# Degree FDTD
#  number of C =    266
#
#
# Degree M.SC(DS)
#  number of C =    267
#
#
# Degree MBA
#  number of A =    168
#
#
# Degree BMS
#  number of A =    163
#
#
# Degree BTD
#  number of A =    163
#
#
# Degree M.SC(IR)
#  number of A =    165
#
#
# Degree BBA-H
#  number of A =    170
#
#
# Degree MS(SE)
#  number of A =    164
#
#
# Degree BS(SE)
#  number of A =    165
#
#
# Degree BS(CS)
#  number of A =    169
#
#
# Degree BSDS
#  number of A =    165
#
#
# Degree BFD
#  number of A =    164
#
#
# Degree MS(CS)
#  number of A =    164
#
#
# Degree MS(BA)
#  number of A =    163
#
#
# Degree BS(IR)
#  number of A =    168
#
#
# Degree ADFD
#  number of A =    163
#
#
# Degree BS(A&F)
#  number of A =    163
#
#
# Degree BSTN
#  number of A =    163
#
#
# Degree MPHIL(IDS)
#  number of A =    163
#
#
# Degree BS(ECO)
#  number of A =    163
#
#
# Degree MPHIL(IR)
#  number of A =    163
#
#
# Degree MS(MGT)
#  number of A =    165
#
#
# Degree BS(SC)
#  number of A =    164
#
#
# Degree PH.D (CS)
#  number of A =    163
#
#
# Degree FDFD
#  number of A =    163
#
#
# Degree MSTN
#  number of A =    163
#
#
# Degree FDTD
#  number of A =    163
#
#
# Degree M.SC(DS)
#  number of A =    163
#
#
# Degree MBA
#  number of W =    130
#
#
# Degree BMS
#  number of W =    127
#
#
# Degree BTD
#  number of W =    125
#
#
# Degree M.SC(IR)
#  number of W =    125
#
#
# Degree BBA-H
#  number of W =    128
#
#
# Degree MS(SE)
#  number of W =    125
#
#
# Degree BS(SE)
#  number of W =    127
#
#
# Degree BS(CS)
#  number of W =    131
#
#
# Degree BSDS
#  number of W =    125
#
#
# Degree BFD
#  number of W =    126
#
#
# Degree MS(CS)
#  number of W =    125
#
#
# Degree MS(BA)
#  number of W =    125
#
#
# Degree BS(IR)
#  number of W =    127
#
#
# Degree ADFD
#  number of W =    125
#
#
# Degree BS(A&F)
#  number of W =    126
#
#
# Degree BSTN
#  number of W =    125
#
#
# Degree MPHIL(IDS)
#  number of W =    125
#
#
# Degree BS(ECO)
#  number of W =    125
#
#
# Degree MPHIL(IR)
#  number of W =    125
#
#
# Degree MS(MGT)
#  number of W =    125
#
#
# Degree BS(SC)
#  number of W =    125
#
#
# Degree PH.D (CS)
#  number of W =    125
#
#
# Degree FDFD
#  number of W =    125
#
#
# Degree MSTN
#  number of W =    125
#
#
# Degree FDTD
#  number of W =    125
#
#
# Degree M.SC(DS)
#  number of W =    125

# %%
Dict={}
for count,i in enumerate(['MBA', 'BMS', 'BTD', 'M.SC(IR)', 'BBA-H', 'MS(SE)', 'BS(SE)',
    'BS(CS)', 'BSDS', 'BFD', 'MS(CS)', 'MS(BA)', 'BS(IR)', 'ADFD',
    'BS(A&F)', 'BSTN', 'MPHIL(IDS)', 'BS(ECO)', 'MPHIL(IR)', 'MS(MGT)',
    'BS(SC)', 'PH.D (CS)', 'FDFD', 'MSTN', 'FDTD', 'M.SC(DS)']):
    dict_grad_counter={}
    for j in ['B+', 'B', 'C+', 'F', 'C', 'A', 'W']:
        dict_grad_counter[j]=grade_calculator(i,j)
    Dict[i]=dict_grad_counter

# %%
Dict
# Out:
# {'MBA': {'B+': 245,
#   'B': 334,
#   'C+': 323,
#   'F': 177,
#   'C': 280,
#   'A': 168,
#   'W': 130},
#  'BMS': {'B+': 240,
#   'B': 323,
#   'C+': 314,
#   'F': 174,
#   'C': 273,
#   'A': 163,
#   'W': 127},
#  'BTD': {'B+': 241,
#   'B': 322,
#   'C+': 314,
#   'F': 172,
#   'C': 266,
#   'A': 163,
#   'W': 125},
#  'M.SC(IR)': {'B+': 239,
#   'B': 321,
#   'C+': 314,
#   'F': 174,
#   'C': 266,
#   'A': 165,
#   'W': 125},
#  'BBA-H': {'B+': 253,
#   'B': 337,
#   'C+': 334,
#   'F': 182,
#   'C': 287,
#   'A': 170,
#   'W': 128},
#  'MS(SE)': {'B+': 241,
#   'B': 320,
#   'C+': 313,
#   'F': 172,
#   'C': 267,
#   'A': 164,
#   'W': 125},
#  'BS(SE)': {'B+': 247,
#   'B': 335,
#   'C+': 319,
#   'F': 175,
#   'C': 277,
#   'A': 165,
#   'W': 127},
#  'BS(CS)': {'B+': 249,
#   'B': 335,
#   'C+': 328,
#   'F': 182,
#   'C': 289,
#   'A': 169,
#   'W': 131},
#  'BSDS': {'B+': 240,
#   'B': 322,
#   'C+': 314,
#   'F': 172,
#   'C': 266,
#   'A': 165,
#   'W': 125},
#  'BFD': {'B+': 239,
#   'B': 322,
#   'C+': 317,
#   'F': 175,
#   'C': 268,
#   'A': 164,
#   'W': 126},
#  'MS(CS)': {'B+': 239,
#   'B': 320,
#   'C+': 313,
#   'F': 172,
#   'C': 267,
#   'A': 164,
#   'W': 125},
#  'MS(BA)': {'B+': 238,
#   'B': 320,
#   'C+': 313,
#   'F': 172,
#   'C': 267,
#   'A': 163,
#   'W': 125},
#  'BS(IR)': {'B+': 246,
#   'B': 325,
#   'C+': 317,
#   'F': 177,
#   'C': 270,
#   'A': 168,
#   'W': 127},
#  'ADFD': {'B+': 237,
#   'B': 321,
#   'C+': 313,
#   'F': 172,
#   'C': 266,
#   'A': 163,
#   'W': 125},
#  'BS(A&F)': {'B+': 237,
#   'B': 321,
#   'C+': 313,
#   'F': 172,
#   'C': 266,
#   'A': 163,
#   'W': 126},
#  'BSTN': {'B+': 237,
#   'B': 320,
#   'C+': 313,
#   'F': 172,
#   'C': 268,
#   'A': 163,
#   'W': 125},
#  'MPHIL(IDS)': {'B+': 238,
#   'B': 320,
#   'C+': 314,
#   'F': 172,
#   'C': 266,
#   'A': 163,
#   'W': 125},
#  'BS(ECO)': {'B+': 237,
#   'B': 320,
#   'C+': 313,
#   'F': 172,
#   'C': 266,
#   'A': 163,
#   'W': 125},
#  'MPHIL(IR)': {'B+': 237,
#   'B': 320,
#   'C+': 314,
#   'F': 172,
#   'C': 266,
#   'A': 163,
#   'W': 125},
#  'MS(MGT)': {'B+': 237,
#   'B': 320,
#   'C+': 313,
#   'F': 172,
#   'C': 266,
#   'A': 165,
#   'W': 125},
#  'BS(SC)': {'B+': 237,
#   'B': 320,
#   'C+': 313,
#   'F': 172,
#   'C': 267,
#   'A': 164,
#   'W': 125},
#  'PH.D (CS)': {'B+': 237,
#   'B': 320,
#   'C+': 314,
#   'F': 172,
#   'C': 266,
#   'A': 163,
#   'W': 125},
#  'FDFD': {'B+': 237,
#   'B': 320,
#   'C+': 314,
#   'F': 172,
#   'C': 266,
#   'A': 163,
#   'W': 125},
#  'MSTN': {'B+': 237,
#   'B': 320,
#   'C+': 313,
#   'F': 172,
#   'C': 266,
#   'A': 163,
#   'W': 125},
#  'FDTD': {'B+': 237,
#   'B': 320,
#   'C+': 313,
#   'F': 172,
#   'C': 266,
#   'A': 163,
#   'W': 125},
#  'M.SC(DS)': {'B+': 237,
#   'B': 320,
#   'C+': 313,
#   'F': 172,
#   'C': 267,
#   'A': 163,
#   'W': 125}}

# %%
Dict['MBA']
# Out:
# {'B+': 245, 'B': 334, 'C+': 323, 'F': 177, 'C': 280, 'A': 168, 'W': 130}

# %%
for i in ['MBA', 'BMS', 'BTD', 'M.SC(IR)', 'BBA-H', 'MS(SE)', 'BS(SE)',
    'BS(CS)', 'BSDS', 'BFD', 'MS(CS)', 'MS(BA)', 'BS(IR)', 'ADFD',
    'BS(A&F)', 'BSTN', 'MPHIL(IDS)', 'BS(ECO)', 'MPHIL(IR)', 'MS(MGT)',
    'BS(SC)', 'PH.D (CS)', 'FDFD', 'MSTN', 'FDTD', 'M.SC(DS)']:
    print(Dict[i],end='\n')
# Out:
# {'B+': 245, 'B': 334, 'C+': 323, 'F': 177, 'C': 280, 'A': 168, 'W': 130}
# {'B+': 240, 'B': 323, 'C+': 314, 'F': 174, 'C': 273, 'A': 163, 'W': 127}
# {'B+': 241, 'B': 322, 'C+': 314, 'F': 172, 'C': 266, 'A': 163, 'W': 125}
# {'B+': 239, 'B': 321, 'C+': 314, 'F': 174, 'C': 266, 'A': 165, 'W': 125}
# {'B+': 253, 'B': 337, 'C+': 334, 'F': 182, 'C': 287, 'A': 170, 'W': 128}
# {'B+': 241, 'B': 320, 'C+': 313, 'F': 172, 'C': 267, 'A': 164, 'W': 125}
# {'B+': 247, 'B': 335, 'C+': 319, 'F': 175, 'C': 277, 'A': 165, 'W': 127}
# {'B+': 249, 'B': 335, 'C+': 328, 'F': 182, 'C': 289, 'A': 169, 'W': 131}
# {'B+': 240, 'B': 322, 'C+': 314, 'F': 172, 'C': 266, 'A': 165, 'W': 125}
# {'B+': 239, 'B': 322, 'C+': 317, 'F': 175, 'C': 268, 'A': 164, 'W': 126}
# {'B+': 239, 'B': 320, 'C+': 313, 'F': 172, 'C': 267, 'A': 164, 'W': 125}
# {'B+': 238, 'B': 320, 'C+': 313, 'F': 172, 'C': 267, 'A': 163, 'W': 125}
# {'B+': 246, 'B': 325, 'C+': 317, 'F': 177, 'C': 270, 'A': 168, 'W': 127}
# {'B+': 237, 'B': 321, 'C+': 313, 'F': 172, 'C': 266, 'A': 163, 'W': 125}
# {'B+': 237, 'B': 321, 'C+': 313, 'F': 172, 'C': 266, 'A': 163, 'W': 126}
# {'B+': 237, 'B': 320, 'C+': 313, 'F': 172, 'C': 268, 'A': 163, 'W': 125}
# {'B+': 238, 'B': 320, 'C+': 314, 'F': 172, 'C': 266, 'A': 163, 'W': 125}
# {'B+': 237, 'B': 320, 'C+': 313, 'F': 172, 'C': 266, 'A': 163, 'W': 125}
# {'B+': 237, 'B': 320, 'C+': 314, 'F': 172, 'C': 266, 'A': 163, 'W': 125}
# {'B+': 237, 'B': 320, 'C+': 313, 'F': 172, 'C': 266, 'A': 165, 'W': 125}
# {'B+': 237, 'B': 320, 'C+': 313, 'F': 172, 'C': 267, 'A': 164, 'W': 125}
# {'B+': 237, 'B': 320, 'C+': 314, 'F': 172, 'C': 266, 'A': 163, 'W': 125}
# {'B+': 237, 'B': 320, 'C+': 314, 'F': 172, 'C': 266, 'A': 163, 'W': 125}
# {'B+': 237, 'B': 320, 'C+': 313, 'F': 172, 'C': 266, 'A': 163, 'W': 125}
# {'B+': 237, 'B': 320, 'C+': 313, 'F': 172, 'C': 266, 'A': 163, 'W': 125}
# {'B+': 237, 'B': 320, 'C+': 313, 'F': 172, 'C': 267, 'A': 163, 'W': 125}

# %%
resultD= pd.DataFrame(Dict)

# %%
resultD.to_csv('resultD.csv')
